# %%
import pandas as pd

# %%
import os

# %%
drivers_dict = {'77': '3',
 '33': '2',
 '44': '1',
 '4': '4',
 '16': '6',
 '11': '5',
 '3': '7',
 '31': '13',
 '55': '8',
 '63': '14',
 '10': '17',
 '18': '10',
 '5': '15',
 '22': '9',
 '99': '12',
 '7': '11',
 '14': '19',
 '6': '18',
 '9': '20',
 '88': '21',
 '47': '16'}

# %%
for filename in os.listdir("."):
    if filename.endswith('avif'):
        number = filename.replace('.avif', '')
        new_name = drivers_dict[number] + '.avif'
        os.rename(filename, '-' + new_name)
# Out:
# 7.avif
# 99.avif
# 77.avif
# .DS_Store
# 6.avif
# 16.avif
# Untitled.ipynb
# 31.avif
# 11.avif
# 10.avif
# 47.avif
# 88.avif
# 33.avif
# 3.avif
# 44.avif
# .ipynb_checkpoints
# 5.avif
# 9.avif
# 18.avif
# 63.avif
# 22.avif
# 55.avif
# 14.avif
# 4.avif

# %%
for filename in os.listdir("."):
    if filename.startswith('-'):
        new_name = filename.replace('-', '')
        os.rename(filename, new_name)
